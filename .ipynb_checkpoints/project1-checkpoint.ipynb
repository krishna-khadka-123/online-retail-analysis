# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('online_retail_dataset.csv')

# %%
df.head()
# Out:
#    InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 0     221958  SKU_1964   White Mug        38  2020-01-01 00:00       1.71
# 1     771155  SKU_1241   White Mug        18  2020-01-01 01:00      41.25
# 2     231932  SKU_1501  Headphones        49  2020-01-01 02:00      29.11
# 3     465838  SKU_1760   Desk Lamp        14  2020-01-01 03:00      76.68
# 4     359178  SKU_1386   USB Cable       -30  2020-01-01 04:00     -68.11
#
#    CustomerID         Country  Discount  PaymentMethod  ShippingCost  \
# 0     37039.0       Australia  0.470000  Bank Transfer         10.79
# 1     19144.0           Spain  0.190000        paypall          9.51
# 2     50472.0         Germany  0.350000  Bank Transfer         23.03
# 3     96586.0     Netherlands  0.140000        paypall         11.08
# 4         NaN  United Kingdom  1.501433  Bank Transfer           NaN
#
#       Category SalesChannel  ReturnStatus ShipmentProvider WarehouseLocation  \
# ...

# %%
df.shape
# Out:
# (49782, 17)

# %%
df.isnull().sum()
# Out:
# InvoiceNo               0
# StockCode               0
# Description             0
# Quantity                0
# InvoiceDate             0
# UnitPrice               0
# CustomerID           4978
# Country                 0
# Discount                0
# PaymentMethod           0
# ShippingCost         2489
# Category                0
# SalesChannel            0
# ReturnStatus            0
# ShipmentProvider        0
# WarehouseLocation    3485
# OrderPriority           0
# dtype: int64

# %% [markdown]
# # droping null customer ids

# %%
df = df.dropna(subset=['CustomerID'])

# %% [markdown]
# # fill the null CustomerID as unknown

# %%
df['CustomerID'].fillna('unknown',inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11936\798473971.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CustomerID'].fillna('unknown',inplace=True)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'Discount', 'PaymentMethod',
#        'ShippingCost', 'Category', 'SalesChannel', 'ReturnStatus',
#        'ShipmentProvider', 'WarehouseLocation', 'OrderPriority'],
#       dtype='object')

# %% [markdown]
# # creating new important columns

# %% [markdown]
# # Feature engineering

# %%
df['TotalSales'] = df['Quantity'] * df['UnitPrice']

# %%
 df['FinalPrice'] = df['TotalSales'] - (df['TotalSales'] * df['Discount'])

# %% [markdown]
# # statistics summary

# %%
df.describe()
# Out:
#            InvoiceNo      Quantity     UnitPrice    CustomerID      Discount  \
# count   44804.000000  44804.000000  44804.000000  44804.000000  44804.000000
# mean   549849.692282     24.896973     50.622735  55032.871775      0.250474
# std    260681.031778     14.150006     28.596901  25913.660157      0.144349
# min    100005.000000      1.000000      1.000000  10001.000000      0.000000
# 25%    323744.750000     13.000000     25.880000  32750.750000      0.130000
# 50%    551099.500000     25.000000     50.490000  55165.000000      0.250000
# 75%    775251.750000     37.000000     75.400000  77306.250000      0.380000
# max    999997.000000     49.000000    100.000000  99998.000000      0.500000
#
#        ShippingCost    TotalSales    FinalPrice
# count  44804.000000  44804.000000  44804.000000
# mean      17.484206   1258.846198    944.451383
# std        7.218483   1088.377301    852.195045
# min        5.000000      1.010000      0.717100
# ...

# %% [markdown]
# # filling the null value as mean in  ShippingCost

# %%
shipping_cost_mean = df['ShippingCost'].mean()
df['ShippingCost'] = df['ShippingCost'].fillna(shipping_cost_mean)

# %%
df['NetRevenue'] = df['FinalPrice'] - df['ShippingCost']

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'] )

# %%
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month_name()
df['Day'] = df['InvoiceDate'].dt.day_name()

# %%
 

df['CustomerID'] = pd.to_numeric(df['CustomerID'], errors='coerce').astype('Int64')

# %%
total_customer=df['CustomerID'].nunique()
print(f'total_customer are:{total_customer}')
# Out:
# total_customer are:35389

# %%
df['WarehouseLocation'].unique()
# Out:
# array(['London', 'Rome', 'Berlin', 'Amsterdam', 'Paris'], dtype=object)

# %% [markdown]
# # filling  WarehouseLocation are NaN as Unknown location

# %%
df['WarehouseLocation'] = df['WarehouseLocation'].fillna('Unknown')

# %%
print(f'min:{df['NetRevenue'].min()}')
print(f'max :{df['NetRevenue'].max()}')
# Out:
# min:-28.3592
# max :4703.4559

# %%
Total_Revenue=df['FinalPrice'].sum()
Total_Revenue
# Out:
# np.float64(42315199.7491)

# %%
df.isnull().sum()
# Out:
# InvoiceNo            0
# StockCode            0
# Description          0
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# CustomerID           0
# Country              0
# Discount             0
# PaymentMethod        0
# ShippingCost         0
# Category             0
# SalesChannel         0
# ReturnStatus         0
# ShipmentProvider     0
# WarehouseLocation    0
# OrderPriority        0
# TotalSales           0
# FinalPrice           0
# NetRevenue           0
# Year                 0
# Month                0
# Day                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Discount, PaymentMethod, ShippingCost, Category, SalesChannel, ReturnStatus, ShipmentProvider, WarehouseLocation, OrderPriority, TotalSales, FinalPrice, NetRevenue, Year, Month, Day]
# Index: []
#
# [0 rows x 23 columns]

# %%
df = df.drop_duplicates()

# %% [markdown]
# # Statical summary

# %%
df.describe()
# Out:
#            InvoiceNo      Quantity                    InvoiceDate  \
# count   44804.000000  44804.000000                          44804
# mean   549849.692282     24.896973  2022-11-01 02:33:43.051513344
# min    100005.000000      1.000000            2020-01-01 00:00:00
# 25%    323744.750000     13.000000            2021-05-31 00:45:00
# 50%    551099.500000     25.000000            2022-10-30 10:30:00
# 75%    775251.750000     37.000000            2024-04-03 15:15:00
# max    999997.000000     49.000000            2025-09-05 05:00:00
# std    260681.031778     14.150006                            NaN
#
#           UnitPrice    CustomerID      Discount  ShippingCost    TotalSales  \
# count  44804.000000       44804.0  44804.000000  44804.000000  44804.000000
# mean      50.622735  55032.871775      0.250474     17.484206   1258.846198
# min        1.000000       10001.0      0.000000      5.000000      1.010000
# ...

# %%
customer_orders = df.groupby('CustomerID')['InvoiceNo'].nunique()
customer_orders[customer_orders > 1]
# Out:
# CustomerID
# 10005    2
# 10010    2
# 10020    2
# 10023    2
# 10045    2
#         ..
# 99943    2
# 99965    2
# 99980    2
# 99986    2
# 99998    2
# Name: InvoiceNo, Length: 8013, dtype: int64

# %%
customer_id = int(input("Enter the CustomerID: "))

orders = df[df['CustomerID'] == customer_id]

print("Total rows:", len(orders))
print("Total unique orders:", orders['InvoiceNo'].nunique())

orders
# Out:
# Enter the CustomerID:  33
# Total rows: 0
# Total unique orders: 0
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Discount, PaymentMethod, ShippingCost, Category, SalesChannel, ReturnStatus, ShipmentProvider, WarehouseLocation, OrderPriority, TotalSales, FinalPrice, NetRevenue, Year, Month, Day]
# Index: []
#
# [0 rows x 23 columns]

# %%
sales_2025 = df[df['Year'] == 2025]
monthly_sales_2025 = sales_2025.groupby('Month')['NetRevenue'].sum().reset_index()

print(monthly_sales_2025)
# Out:
#        Month   NetRevenue
# 0      April  611276.2137
# 1     August  650197.0551
# 2   February  570222.9180
# 3    January  631351.8547
# 4       July  602812.4875
# 5       June  582128.5246
# 6      March  633968.6743
# 7        May  612956.3823
# 8  September   83387.7261

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(monthly_sales_2025['Month'], monthly_sales_2025['NetRevenue'], marker='o')

plt.title('Gross Sales by Month (2025)')
plt.xlabel('Month')
plt.ylabel('Net Revenue')
plt.show()

# %%
 
# Only numeric columns
numeric_df = df.select_dtypes(include=['int64','float64'])

# Correlation matrix
corr_matrix = numeric_df.corr()
corr_matrix
# Out:
#               InvoiceNo  Quantity  UnitPrice  CustomerID  Discount  \
# InvoiceNo      1.000000  0.007537  -0.013234    0.000730 -0.000147
# Quantity       0.007537  1.000000  -0.003724    0.002889 -0.000625
# UnitPrice     -0.013234 -0.003724   1.000000    0.000065 -0.005517
# CustomerID     0.000730  0.002889   0.000065    1.000000  0.010822
# Discount      -0.000147 -0.000625  -0.005517    0.010822  1.000000
# ShippingCost   0.001501 -0.004307   0.004842    0.004071 -0.003891
# TotalSales    -0.005305  0.656682   0.653457    0.001311 -0.005811
# FinalPrice    -0.005382  0.629526   0.626960   -0.001080 -0.219464
# NetRevenue    -0.005395  0.629548   0.626904   -0.001114 -0.219426
#
#               ShippingCost  TotalSales  FinalPrice  NetRevenue
# InvoiceNo         0.001501   -0.005305   -0.005382   -0.005395
# Quantity         -0.004307    0.656682    0.629526    0.629548
# UnitPrice         0.004842    0.653457    0.626960    0.626904
# ...

# %% [markdown]
# ### This heatmap shows the correlation between numeric variables.
# ### Blue means strong positive correlation, red means negative.
# ### For example, Quantity and FinalPrice are strongly positively correlated — more items sold leads to higher revenue.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# top selling product
top_selling=df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)

# %%
plt.figure(figsize=(12,6))

colors = ['red','yellow','blue','green','black','orange','purple','cyan','magenta','brown']
bars = plt.bar(top_selling.index, top_selling.values, color=colors)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, int(yval), ha='center', va='bottom', fontweight='bold')


plt.title('Top 10 Selling Products', fontsize=16, fontweight='bold')
plt.xlabel('Product', fontsize=12)
plt.ylabel('Quantity Sold', fontsize=12)
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
plt.show()

# %% [markdown]
#  # monthly revenue of all years

# %%
monthly_sales = df.groupby('Month')['FinalPrice'].sum().reset_index()
monthly_sales
monthly_sales['FinalPrice_formatted'] = monthly_sales['FinalPrice'].apply(lambda x: f"${x:,.2f}")
monthly_sales
# Out:
#         Month    FinalPrice FinalPrice_formatted
# 0       April  3.704115e+06        $3,704,114.64
# 1      August  3.810195e+06        $3,810,194.85
# 2    December  3.145271e+06        $3,145,271.23
# 3    February  3.472194e+06        $3,472,193.86
# 4     January  3.809589e+06        $3,809,589.15
# 5        July  3.722375e+06        $3,722,374.61
# 6        June  3.645877e+06        $3,645,877.42
# 7       March  3.836896e+06        $3,836,896.20
# 8         May  3.734436e+06        $3,734,436.08
# 9    November  3.115582e+06        $3,115,581.83
# 10    October  3.187895e+06        $3,187,895.45
# 11  September  3.130774e+06        $3,130,774.44

# %%
colors = ['red','yellow','blue','green','black','orange','purple','cyan','magenta','brown']
plt.figure(figsize=(10,5))
sns.barplot(x='Month', y='FinalPrice', data=monthly_sales, palette=colors)
plt.ylabel('Revenue ($)')
plt.xlabel('Month')
plt.title('Monthly Revenue')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f"${y:,.0f}"))  # format y-axis as $ 
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11936\580511009.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Month', y='FinalPrice', data=monthly_sales, palette=colors)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11936\580511009.py:3: UserWarning:
# The palette list has fewer values (10) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Month', y='FinalPrice', data=monthly_sales, palette=colors)

# %% [markdown]
# # highest revenue products:

# %%
top_products = df.groupby('Description')['FinalPrice'].sum() \
                 .sort_values(ascending=False) \
                 .head(10) \
                 .reset_index()
top_products
top_products['FinalPrice_formatted'] = top_products['FinalPrice'].apply(lambda x: f"${x:,.2f}")
top_products
# Out:
#       Description    FinalPrice FinalPrice_formatted
# 0       White Mug  3.950316e+06        $3,950,316.26
# 1      Wall Clock  3.894783e+06        $3,894,783.09
# 2       Desk Lamp  3.890642e+06        $3,890,642.47
# 3       USB Cable  3.883872e+06        $3,883,871.56
# 4        Backpack  3.859457e+06        $3,859,457.36
# 5        Blue Pen  3.822014e+06        $3,822,013.80
# 6      Headphones  3.818923e+06        $3,818,923.07
# 7  Wireless Mouse  3.807658e+06        $3,807,658.36
# 8         T-shirt  3.802392e+06        $3,802,392.37
# 9        Notebook  3.802158e+06        $3,802,158.06

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Description', y='FinalPrice', data=top_products, palette='viridis')
plt.ylabel('Revenue ($)')
plt.xlabel('Product')
plt.title('Top 10 Products by Revenue')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f"${y:,.0f}"))
plt.xticks(rotation=45, ha='right')  # rotate product names so they fit
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11936\376164933.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Description', y='FinalPrice', data=top_products, palette='viridis')

# %% [markdown]
# # product category generates the most revenue.

# %%
category_revenue = df.groupby('Category')['FinalPrice'].sum().sort_values(ascending=False).reset_index()

# %%
from matplotlib.ticker import FuncFormatter

plt.figure(figsize=(10,6))

bars = plt.bar(category_revenue['Category'], category_revenue['FinalPrice'], color=['red','yellow','blue','green','black'])
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda y, _: f"${y:,.0f}"))
# Add value top of bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01*yval, f"${yval:,.0f}", ha='center', va='bottom', fontweight='bold')

# Titles and labels
plt.title('Revenue by Category', fontsize=16, fontweight='bold')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Revenue ($)', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # country sales analysis

# %%
result = df.groupby('Country')['FinalPrice'].sum().sort_values(ascending=False).reset_index()
result['FinalPrice'] = result['FinalPrice'].map('${:,.2f}'.format)
result
# Out:
#            Country     FinalPrice
# 0          Belgium  $3,628,107.84
# 1    United States  $3,609,185.48
# 2           France  $3,577,957.99
# 3           Sweden  $3,555,066.18
# 4          Germany  $3,548,894.03
# 5   United Kingdom  $3,539,162.23
# 6         Portugal  $3,521,324.22
# 7            Spain  $3,512,489.73
# 8           Norway  $3,495,541.63
# 9            Italy  $3,478,254.08
# 10       Australia  $3,440,394.92
# 11     Netherlands  $3,408,821.41

# %% [markdown]
# # top customer

# %%
res=df.groupby('CustomerID')['FinalPrice'].sum().sort_values(ascending=False).head(10).reset_index()
res['FinalPrice']=res['FinalPrice'].map('${:,.2f}'.format)
res
# Out:
#    CustomerID FinalPrice
# 0       84431  $9,777.49
# 1       81067  $9,678.65
# 2       81631  $8,690.41
# 3       98923  $8,655.47
# 4       80001  $8,547.84
# 5       76402  $8,235.68
# 6       29700  $8,033.66
# 7       72172  $7,874.69
# 8       52808  $7,843.39
# 9       26371  $7,723.45

# %% [markdown]
# # most use payment metjhod

# %%
df['PaymentMethod'].value_counts().reset_index()
# Out:
#    PaymentMethod  count
# 0  Bank Transfer  15086
# 1    Credit Card  14907
# 2        paypall  14811

# %% [markdown]
# # selling channels

# %%
ress=df.groupby('SalesChannel')['FinalPrice'].sum().reset_index()
ress['FinalPrice']=ress['FinalPrice'].map('${:,.2f}'.format)
ress
# Out:
#   SalesChannel      FinalPrice
# 0     In-store  $21,095,902.96
# 1       Online  $21,219,296.79

# %%
df.head()
# Out:
#    InvoiceNo StockCode   Description  Quantity         InvoiceDate  UnitPrice  \
# 0     221958  SKU_1964     White Mug        38 2020-01-01 00:00:00       1.71
# 1     771155  SKU_1241     White Mug        18 2020-01-01 01:00:00      41.25
# 2     231932  SKU_1501    Headphones        49 2020-01-01 02:00:00      29.11
# 3     465838  SKU_1760     Desk Lamp        14 2020-01-01 03:00:00      76.68
# 5     744167  SKU_1006  Office Chair        47 2020-01-01 05:00:00      70.16
#
#    CustomerID      Country  Discount  PaymentMethod  ...  ReturnStatus  \
# 0       37039    Australia      0.47  Bank Transfer  ...  Not Returned
# 1       19144        Spain      0.19        paypall  ...  Not Returned
# 2       50472      Germany      0.35  Bank Transfer  ...      Returned
# 3       96586  Netherlands      0.14        paypall  ...  Not Returned
# 5       53887       Sweden      0.48    Credit Card  ...  Not Returned
#
# ...

# %%
df.to_csv('online_retail_cleaned.csv', index=False)

# %%
dd=pd.read_csv('online_retail_cleaned.csv')
dd
# Out:
#        InvoiceNo StockCode   Description  Quantity          InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00:00
# 4         744167  SKU_1006  Office Chair        47  2020-01-01 05:00:00
# ...          ...       ...           ...       ...                  ...
# 44799     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00:00
# 44800     296698  SKU_1930     USB Cable         7  2025-09-05 02:00:00
# 44801     177622  SKU_1766  Office Chair        43  2025-09-05 03:00:00
# 44802     701213  SKU_1602      Notebook        48  2025-09-05 04:00:00
# 44803     772215  SKU_1832     White Mug        30  2025-09-05 05:00:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  ...  \
# ...
